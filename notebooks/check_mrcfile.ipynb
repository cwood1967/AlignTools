# %%
import mrcfile
from matplotlib import pyplot as plt
import numpy as np

# %%
mrc = mrcfile.mmap("stack_ali.mrc", mode="r+")
mrc.data.shape
# Out:
# (1700, 13440, 12096)

# %%
m
plt.figure(figsize=(16,16))
plt.imshow(mrc.data[67])

# %%
for i in range(10):
    print(mrc.data[i+300].mean())
# Out:
# -10.543065403606466
# -9.68205584859812
# -9.659163110050155
# -8.979102928063586
# -8.12686234577743
# -7.437036993978726
# -8.497050173512692
# -7.9168277970186915
# -7.851164930309508
# -7.399312973887471

# %%
x = mrc.data[56]

# %%
h, hx = np.histogram(x, bins=256, range=(-127,128))

# %%
plt.plot(hx[:-1], h)
